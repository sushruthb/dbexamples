# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("StreamingExample").getOrCreate()

streaming_df = spark.read.option("header", True).option("inferSchema", True).csv("dbfs:/Volumes/workspace/dbricks/db/employee_salary_dataset.csv")


display(streaming_df)

streaming_df.write.mode("overwrite").csv("dbfs:/Volumes/workspace/dbricks/db/csv/employee_salary_dataset")

display(dbutils.fs.ls("dbfs:/Volumes/workspace/dbricks/db/csv/employee_salary_dataset"))

# %%
streaming_df.write.mode("overwrite").json("dbfs:/Volumes/workspace/dbricks/db/json/employee_salary_dataset")

display(dbutils.fs.ls("dbfs:/Volumes/workspace/dbricks/db/json/employee_salary_dataset"))

# %%
streaming_df.write.json("dbfs:/Volumes/workspace/dbricks/db/json/employee_salary_dataset",mode="overwrite")

streaming_df.write.mode("overwrite").json("dbfs:/Volumes/workspace/dbricks/db/json/employee_salary_dataset")

streaming_df.write.format("json").mode("overwrite").save("dbfs:/Volumes/workspace/dbricks/db/json/employee_salary_dataset")

# %%
#spark.read.json("dbfs:/Volumes/workspace/dbricks/db/json/employee_salary_dataset/part-00000-tid-1691576827530895205-1402e7e6-a25a-4826-a0f2-adf78a9fc425-271-1-c000.json").display()

spark.read.json(
  "dbfs:/Volumes/workspace/dbricks/db/json/employee_salary_dataset/part-00000-tid-1691576827530895205-1402e7e6-a25a-4826-a0f2-adf78a9fc425-271-1-c000.json"
).display()

# %%
      
print(
  dbutils.fs.head(
    "dbfs:/Volumes/workspace/dbricks/db/json/employee_salary_dataset/part-00000-tid-1691576827530895205-1402e7e6-a25a-4826-a0f2-adf78a9fc425-271-1-c000.json"
  )
)

# %%
      
print(
  dbutils.fs.head("dbfs:/Volumes/workspace/dbricks/db/csv/employee_salary_dataset/part-00000-tid-8010816231464056348-24138d85-e432-47b2-8f17-fda5a6aa69e3-266-1-c000.csv"
  )
)

# %%
spark.sql("SHOW CATALOGS").show()

# %%
# %sql
SHOW SCHEMAS IN workspace

# %%
# %fs
ls /Workspace/Spark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("DeltaLakeLocal") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# %%
data = [(1, "IN", 100), (2, "US", 200)]
df = spark.createDataFrame(data, ["id", "region", "amount"])

df.write.format("delta").mode("overwrite").save("/Volumes/workspace/dbricks/db/sales")

# %%
spark.read.format("delta").load("/Volumes/workspace/dbricks/db/sales").show()
